# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('labeled_patient_dataset.csv', low_memory=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1734 entries, 0 to 1733
# Columns: 792 entries, Unnamed: 0 to label
# dtypes: float64(76), int64(592), object(124)
# memory usage: 10.5+ MB

# %%
df_objects = df.select_dtypes('object')

# %%
df_objects.apply()
# Out:
#      ices_caseid                      ices_addcomm1 ices_othereth  \
# 0       021-0001                                NaN           NaN
# 1       021-0002                                NaN           NaN
# 2       021-0003                                NaN           NaN
# 3       021-0004                                NaN           NaN
# 4       021-0006                                NaN           NaN
# ...          ...                                ...           ...
# 1729    050-0003                                NaN           NaN
# 1730    050-0007                                NaN           NaN
# 1731    050-0008                                NaN           NaN
# 1732    050-0010  sample dried up needs to resample           NaN
# 1733    050-0011                                NaN           NaN
#
#      ices_addcomm2 ices_lastworking ices_howother ices_datelastdose  \
# 0              NaN         1/1/2008           NaN           00:00.0
# 1              NaN         1/1/2006           NaN           00:00.0
# 2              NaN         1/1/2008           NaN           00:00.0
# 3              NaN                .           NaN           00:00.0
# 4              NaN         1/1/2013           NaN           00:00.0
# ...            ...              ...           ...               ...
# 1729           NaN        8/21/2019           NaN           00:00.0
# 1730           NaN         1/1/2010           NaN           00:00.0
# 1731           NaN                .        Clinic           00:00.0
# 1732           NaN         1/1/2009           NaN           00:00.0
# 1733           NaN         1/1/2017           NaN           00:00.0
#
#      ices_doseaddcomm1 ices_lengthosat ices_otherprescript  ...  \
# 0                  NaN              60                 NaN  ...
# 1                  NaN             115                 NaN  ...
# 2                  NaN              12                 NaN  ...
# 3                  NaN              48                 NaN  ...
# 4                  NaN             108                 NaN  ...
# ...                ...             ...                 ...  ...
# 1729               NaN              48                 NaN  ...
# 1730               NaN              54                 NaN  ...
# 1731               NaN             138                 NaN  ...
# 1732               NaN               3                 NaN  ...
# 1733               NaN              24                 NaN  ...
#
#                     ices_doseaddcomm2 ices_urinelabel  \
# 0                                 NaN             NaN
# 1                                 NaN             NaN
# 2                                 NaN             NaN
# 3                                 NaN             NaN
# 4                                 NaN             NaN
# ...                               ...             ...
# 1729                              NaN             NaN
# 1730                              NaN             NaN
# 1731                              NaN             NaN
# 1732  SAMPLE DRIED UP NEED NEW SAMPLE             NaN
# 1733                              NaN             NaN
#
#                                           ices_addcomm3 ices_dosetime3  \
# 0                                                   NaN             27
# 1                                                   NaN              6
# 2                                                   NaN              9
# 3                                                   NaN             39
# 4                                                   NaN              3
# ...                                                 ...            ...
# 1729  Failed treatment @ 2020-01-23 came back before...           0.06
# 1730                                                NaN             15
# 1731                                                NaN           3.75
# 1732                                                NaN           0.25
# 1733                                                NaN           0.75
#
#      ices_addcomm6 ices_dosetime6                     ices_addcomm9  \
# 0              NaN             30                               NaN
# 1              NaN              9                               NaN
# 2              NaN             12                               NaN
# 3              NaN             42                               NaN
# 4              NaN              6                               NaN
# ...            ...            ...                               ...
# 1729           NaN           1.16  Restarts within one month cutoff
# 1730           NaN             18                               NaN
# 1731           NaN           1.13                               NaN
# 1732           NaN              1                               NaN
# 1733           NaN           0.03                               NaN
#
#      ices_dosetime9                                   ices_addcomm12  \
# 0                33                                              NaN
# 1                 3                                              NaN
# 2                15                                              NaN
# 3                45  Transferred to another provider @ March 7, 2019
# 4                 9                                              NaN
# ...             ...                                              ...
# 1729           0.03                                              NaN
# 1730             21                                              NaN
# 1731           4.13                                              NaN
# 1732            1.5                                              NaN
# 1733           0.06                                              NaN
#
#      ices_dosetime12
# 0                 36
# 1                  1
# 2                  2
# 3              46.25
# 4                 12
# ...              ...
# 1729            0.03
# 1730              24
# 1731            7.13
# 1732            0.43
# 1733            3.06
#
# [1734 rows x 124 columns]

# %%
df[pd.to_numeric(df['ices_daysfriendsconflict'], errors='coerce').isnull()]['ices_daysfriendsconflict'].value_counts()
# Out:
# 5 to 6    1
# Name: ices_daysfriendsconflict, dtype: int64

# %%
pd.to_numeric(df['ices_lengthosat'], errors='coerce').isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1729    False
# 1730    False
# 1731    False
# 1732    False
# 1733    False
# Name: ices_lengthosat, Length: 1734, dtype: bool

# %%
num_nulls = {}
for col in df_objects.columns:
    num_nulls[col] = sum(pd.to_numeric(df_objects[col], errors='coerce').isnull())

# %%
sorted(num_nulls.items(), key=lambda x: x[1], reverse=True)
# Out:
# [('ices_caseid', 1734),
#  ('ices_addcomm1', 1734),
#  ('ices_othereth', 1734),
#  ('ices_lastworking', 1734),
#  ('ices_howother', 1734),
#  ('ices_datelastdose', 1734),
#  ('ices_otherprescript', 1734),
#  ('ices_b9name', 1734),
#  ('ices_urinestartbase', 1734),
#  ('ices_urineendbase', 1734),
#  ('ices_dose3', 1734),
#  ('ices_urinestart3', 1734),
#  ('ices_urineend3', 1734),
#  ('ices_dose6', 1734),
#  ('ices_urinestart6', 1734),
#  ('ices_urineend6', 1734),
#  ('ices_dose9', 1734),
#  ('ices_urinestart9', 1734),
#  ('ices_urineend9', 1734),
#  ('ices_dose12', 1734),
#  ('ices_urinestart12', 1734),
#  ('ices_urineend12', 1734),
#  ('ices_postgenoa', 1734),
#  ('ices_ethmixed', 1734),
#  ('ices_occupation', 1734),
#  ('ices_nameofscript', 1734),
#  ('ices_nocontinuescript', 1734),
#  ('ices_opioiddependence', 1734),
#  ('ices_howotherdepend', 1734),
#  ('Ices_currentopoth', 1734),
#  ('ices_edreasonother', 1734),
#  ('ices_obtainnal', 1734),
#  ('ices_subvape', 1734),
#  ('ices_otherosat', 1734),
#  ('ices_goalsosat', 1734),
#  ('ices_anyotherosat', 1734),
#  ('ices_opioidmedname', 1734),
#  ('ices_famotherexpl', 1734),
#  ('ices_othersub', 1734),
#  ('ices_mjmethodother', 1734),
#  ('ices_mjtype', 1734),
#  ('ices_mjsituationother', 1734),
#  ('ices_mjeffectother', 1734),
#  ('ices_othersideeffect', 1734),
#  ('ices_yesnegativemotion', 1734),
#  ('ices_diseasemj', 1734),
#  ('ices_othermjobtain', 1734),
#  ('ices_medreasonmj', 1734),
#  ('ices_whereother', 1734),
#  ('ices_legalprescriptmj', 1734),
#  ('ices_salivadate', 1734),
#  ('ices_salivanumber', 1734),
#  ('ices_urinelabel', 1734),
#  ('ices_addcomm3', 1734),
#  ('ices_addcomm6', 1734),
#  ('ices_addcomm9', 1734),
#  ('ices_addcomm12', 1734),
#  ('ices_mjlegal', 1733),
#  ('ices_mjeffecttreatment', 1733),
#  ('ices_doseaddcomm2', 1733),
#  ('ices_b4name', 1732),
#  ('ices_medhistory', 1732),
#  ('ices_mjlegaluse', 1732),
#  ('ices_doseaddcomm1', 1731),
#  ('ices_b3amount', 1730),
#  ('ices_timesfraud', 1724),
#  ('ices_currentmeds', 1723),
#  ('ices_b4amount', 1721),
#  ('ices_mentalhealthmeds', 1721),
#  ('ices_addcomm2', 1720),
#  ('ices_b6amount', 1716),
#  ('ices_b9amount', 1716),
#  ('ices_b5amount', 1712),
#  ('ices_b7amount', 1712),
#  ('ices_b2amount', 1710),
#  ('ices_b1amount', 1705),
#  ('ices_averagemjuse', 1701),
#  ('ices_b8amount', 1682),
#  ('ices_timesselldrug', 1632),
#  ('ices_b9days', 1540),
#  ('ices_ivtimes', 1528),
#  ('ices_ivshare', 1525),
#  ('ices_yeshospital', 1459),
#  ('ices_opioidmoney', 1388),
#  ('ices_unclenum', 1384),
#  ('ices_naltimes', 1361),
#  ('ices_timesod', 1242),
#  ('ices_edtimes', 1197),
#  ('ices_othercrime', 1151),
#  ('ices_missedwork', 1126),
#  ('ices_mjmoney', 918),
#  ('ices_dayspartnerconflict', 722),
#  ('ices_daysfriendsconflict', 374),
#  ('ices_daysrelativesconflict', 246),
#  ('ices_regularuse', 203),
#  ('ices_totalyearsused', 151),
#  ('ices_osathour', 99),
#  ('ices_currentdosetime', 63),
#  ('ices_dosetime3', 58),
#  ('ices_dosetime6', 49),
#  ('ices_mealhour', 32),
#  ('ices_weight', 14),
#  ('ices_dosetime9', 13),
#  ('ices_timessex', 12),
#  ('ices_height', 8),
#  ('ices_dosetime12', 7),
#  ('ices_lengthosat', 6),
#  ('ices_selldrug', 6),
#  ('ices_ofvehicleday', 5),
#  ('ices_numsex', 4),
#  ('ices_formunempl', 4),
#  ('ices_propertyday', 4),
#  ('ices_fromvehicleday', 4),
#  ('ices_length12', 4),
#  ('ices_numpaidwork', 3),
#  ('ices_b5cocaine', 2),
#  ('ices_b7amph', 2),
#  ('ices_length3', 2),
#  ('ices_length9', 2),
#  ('ices_b2heroin', 1),
#  ('ices_b4benzo', 1),
#  ('ices_b6crack', 1),
#  ('ices_b8cannabis', 1),
#  ('ices_length6', 1)]

# %% [markdown]
# 1) try pd.to_numerics(error='coerce') --> converts any non-numeric entry to a NULL
# 2) count the nulls
# 3) if the nulls are really small then dont drop the column

# %% [markdown]
# * ices_daysfriendsconflict : convert to 0
# * ices_regularuse : convert to 0
# * ices_totalyearsused : split string, if num take num else 0
